# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
import xgboost as xgb
warnings.filterwarnings('ignore')
import csv
import codecs
 
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.model_selection import GridSearchCV

# %%
with codecs.open("Consumer_Reports_2018.csv", "r", "Shift-JIS", "ignore") as file:
    df = pd.read_table(file, delimiter=",")

# %%
df
# Out:
#                                   Model  Price_as_tested  4spd  6over  cvt  \
# 0                     Acura ILX Premium          31600.0     0      1    0
# 1                        Acura MDX Tech          51425.0     0      1    0
# 2                             Acura RDX          40100.0     0      1    0
# 3                        Acura RLX Tech          58400.0     0      1    0
# 4                        Acura TLX 2.4L          39375.0     0      1    0
# 5                      Acura TLX SH-AWD          39375.0     0      1    0
# 6                         Alfa Romeo 4C          60900.0     0      1    0
# 7                     Alfa Romeo Giulia          55947.5     0      1    0
# 8                    Alfa Romeo Stelvio          42995.0     0      1    0
# 9                       Audi A3 Premium          37800.0     0      1    0
# 10                 Audi A4 Premium Plus          40250.0     0      1    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 22 columns):
# Model              313 non-null object
# Price_as_tested    313 non-null float64
# 4spd               313 non-null int64
# 6over              313 non-null int64
# cvt                313 non-null int64
# Disp               313 non-null float64
# Hp                 313 non-null int64
# AWD                313 non-null int64
# 4WD_dummy          313 non-null int64
# rear               313 non-null int64
# SUV                313 non-null int64
# Pickup             313 non-null int64
# Minivan            313 non-null int64
# Sports             313 non-null int64
# Luxuary            313 non-null int64
# Curb Weight(lb)    310 non-null float64
# length(inch)       312 non-null float64
# MPG_ovarall        269 non-null float64
# Reliability        313 non-null int64
# Electric           313 non-null int64
# Hybrid             313 non-null int64
# ...

# %%
df.shape
# Out:
# (313, 22)

# %%
plt.figure(figsize=(12,9))

sns.heatmap(df.corr(), annot=True, fmt='.2f')
plt.show()

# %%
df['y'] = df['Price_as_tested']
df2 = df.drop('Price_as_tested', axis=1)

# %%
df2.describe()
# Out:
#              4spd       6over         cvt        Disp          Hp         AWD  \
# count  313.000000  313.000000  313.000000  313.000000  313.000000  313.000000
# mean     0.003195    0.782748    0.169329    2.777316  261.658147    0.555911
# std      0.056523    0.413036    0.375643    1.317959  100.130947    0.497660
# min      0.000000    0.000000    0.000000    0.000000   78.000000    0.000000
# 25%      0.000000    1.000000    0.000000    2.000000  180.000000    0.000000
# 50%      0.000000    1.000000    0.000000    2.500000  258.000000    1.000000
# 75%      0.000000    1.000000    0.000000    3.500000  320.000000    1.000000
# max      1.000000    1.000000    1.000000    6.700000  607.000000    1.000000
#
#         4WD_dummy        rear         SUV      Pickup      ...        \
# count  313.000000  313.000000  313.000000  313.000000      ...
# mean     0.124601    0.316294    0.361022    0.063898      ...
# std      0.330794    0.465774    0.481066    0.244962      ...
# ...

# %%
df2[df2.columns[df2.isnull().sum()>0]].isnull().sum()
# Out:
# Curb Weight(lb)     3
# length(inch)        1
# MPG_ovarall        44
# dtype: int64

# %%
train = df2.dropna(subset=["y"])
train["MPG_ovarall"].describe()
# Out:
# count    269.000000
# mean      27.364312
# std       16.559965
# min       14.000000
# 25%       20.000000
# 50%       24.000000
# 75%       29.000000
# max      139.000000
# Name: MPG_ovarall, dtype: float64

# %%
ax = sns.distplot(train["MPG_ovarall"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-8ebae2da5e95> in <module>()
# ----> 1 ax = sns.distplot(train["MPG_ovarall"])
#       2 plt.show()
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210     if hist:
#     211         if bins is None:
# --> 212             bins = min(_freedman_diaconis_bins(a), 50)
#     213         hist_kws.setdefault("alpha", 0.4)
#     214         hist_kws.setdefault("normed", norm_hist)
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/seaborn/distributions.py in _freedman_diaconis_bins(a)
#      34         return int(np.sqrt(a.size))
#      35     else:
# ---> 36         return int(np.ceil((a.max() - a.min()) / h))
#      37
#      38
#
# ...

# %%
train.shape
# Out:
# (313, 23)

# %%
train[train.columns[train.isnull().sum()>0]].isnull().sum()
# Out:
# Curb Weight(lb)     3
# length(inch)        1
# MPG_ovarall        44
# dtype: int64

# %%
ax = sns.distplot(y_train)
plt.show()

# %%
df2["price"]
# Out:
# <bound method Series.max of 0       31600.0
# 1       51425.0
# 2       40100.0
# 3       58400.0
# 4       39375.0
# 5       39375.0
# 6       60900.0
# 7       55947.5
# 8       42995.0
# 9       37800.0
# 10      40250.0
# 11      52450.0
# 12      60800.0
# 13     100200.0
# 14      99200.0
# 15      34450.0
# 16      47900.0
# 17      68695.0
# 18      54425.0
# 19      50400.0
# 20      42950.0
# 21      42950.0
# 22      51745.0
# 23      60250.0
# 24      77625.0
# 25      97250.0
# 26     119900.0
# 27      47975.0
# 28      34900.0
# 29      48575.0
#          ...
# 283     58365.0
# 284     27020.0
# 285     22797.5
# 286     30100.0
# 287     28217.0
# 288     30380.0
# 289     30380.0
# 290     67335.0
# 291     39682.5
# 292     34360.0
# 293     40625.0
# 294     17347.5
# 295     16500.0
# 296     39745.0
# 297     26155.0
# 298     28540.0
# 299     30807.5
# 300     25965.0
# 301     31292.5
# 302     24095.0
# 303     24095.0
# 304     34650.0
# 305     34650.0
# ...

# %%
max(df2["price"])
# Out:
# 456287.5

# %%
df2["price"].max()
# Out:
# 456287.5

# %%
mask = df2["price"] == 456287.5

# %%
df2[mask]
# Out:
#                                       Model  4spd  6over  cvt  Disp   Hp  AWD  \
# 188  Lincoln Continental Select (2.7T, AWD)     0      1    0   2.7  335    1
#
#      4WD_dummy  rear  SUV    ...     Sports  Luxuary  Curb Weight(lb)  \
# 188          0     0    0    ...          0        1           4540.0
#
#      length(inch)  MPG_ovarall  Reliability  Electric  Hybrid  Hybrid(option)  \
# 188         201.0         20.0            2         0       0               0
#
#         price
# 188  456287.5
#
# [1 rows x 22 columns]

# %%
df_exp = df2.drop("Model", axis=1)

# %%
y = df_exp["price"]

# %%
x = df_exp.drop("price", axis=1)

# %%
x.head()
# Out:
#    4spd  6over  cvt  Disp   Hp  AWD  4WD_dummy  rear  SUV  Pickup  Minivan  \
# 0     0      1    0   2.4  201    0          0     0    0       0        0
# 1     0      1    0   3.5  290    1          0     0    1       0        0
# 2     0      1    0   3.5  279    1          0     0    1       0        0
# 3     0      1    0   3.5  310    1          0     0    0       0        0
# 4     0      1    0   2.4  206    0          0     0    0       0        0
#
#    Sports  Luxuary  Curb Weight(lb)  length(inch)  MPG_ovarall  Reliability  \
# 0       0        1           3100.0         182.0         28.0            1
# 1       0        1           4200.0         196.0         21.0            2
# 2       0        1           3850.0         184.0         22.0            4
# 3       0        1           3930.0         198.0         23.0            2
# 4       0        1           3480.0         190.0         27.0            2
#
#    Electric  Hybrid  Hybrid(option)
# ...

# %%
y.describe()
# Out:
# count       313.000000
# mean      47254.942492
# std       35508.928802
# min       13975.000000
# 25%       29000.000000
# 50%       38762.500000
# 75%       53700.000000
# max      456287.500000
# Name: price, dtype: float64

# %%
x[x.columns[x.isnull().sum()>0]].isnull().sum()
x = x.dropna(subset=["price"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-912d95fe2ede> in <module>()
#       1 x[x.columns[x.isnull().sum()>0]].isnull().sum()
# ----> 2 x = x.dropna(subset=["y"])
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    3487                 check = indices == -1
#    3488                 if check.any():
# -> 3489                     raise KeyError(list(np.compress(check, subset)))
#    3490                 agg_obj = self.take(indices, axis=agg_axis)
#    3491
#
# KeyError: ['y']

# %%
x[x.columns[x.isnull().sum()>0]].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# feature importance using random forest
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=40, max_features='auto')
rf.fit(x, y)
print('Training done using Random Forest')

ranking = np.argsort(-rf.feature_importances_)
f, ax = plt.subplots(figsize=(11, 9))
sns.barplot(x=rf.feature_importances_[ranking], y=x.columns.values[ranking], orient='h')
ax.set_xlabel("feature importance")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-cc9b967dc986> in <module>()
#       2 from sklearn.ensemble import RandomForestRegressor
#       3 rf = RandomForestRegressor(n_estimators=40, max_features='auto')
# ----> 4 rf.fit(x, y)
#       5 print('Training done using Random Forest')
#       6
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     333                     t, self, X, y, sample_weight, i, len(trees),
#     334                     verbose=self.verbose, class_weight=self.class_weight)
# --> 335                 for i, t in enumerate(trees))
#     336
#     337             # Collect newly grown trees
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     981             # remaining jobs.
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-118-e29f2808e1a2> in <module>()
#       2 from sklearn.ensemble import RandomForestRegressor
#       3 rf = RandomForestRegressor(n_estimators=40, max_features='auto')
# ----> 4 rf.fit(x, y)
#       5 print('Training done using Random Forest')
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     333                     t, self, X, y, sample_weight, i, len(trees),
#     334                     verbose=self.verbose, class_weight=self.class_weight)
# --> 335                 for i, t in enumerate(trees))
#     336
#     337             # Collect newly grown trees
#
# ~/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     981             # remaining jobs.
# ...
