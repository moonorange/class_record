# %% [markdown]
# # 学習記録４−１

# %% [markdown]
# numpyは多次元配列数値計算用モジュール
# matplotlibは表などを出力できる
# seabornはmatplotlibのラッパー

# %% [markdown]
# # 学習記録演習

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # 前処理

# %%
drop_elements = ['0', '763', '723']

# %%
df = pd.read_csv("mitaka.csv")
df["age"] = df["0"]
df["m_population"] = df["763"]
df["f_population"] = df["723"]
mitaka_info = df.drop(drop_elements, axis=1)
mitaka_info
# Out:
#      age  m_population  f_population
# 0      1           801           734
# 1      2           839           793
# 2      3           844           790
# 3      4           879           807
# 4      5           802           778
# 5      6           850           812
# 6      7           878           776
# 7      8           803           835
# 8      9           852           767
# 9     10           795           733
# 10    11           801           719
# 11    12           778           772
# 12    13           727           687
# 13    14           776           702
# 14    15           724           718
# 15    16           792           772
# 16    17           775           770
# 17    18           859           819
# 18    19           967           977
# 19    20          1034          1032
# 20    21          1009          1071
# 21    22          1038          1161
# 22    23          1187          1209
# 23    24          1218          1202
# ...

# %% [markdown]
# # ４−１

# %%
m_p = mitaka_info["m_population"]
f_p = mitaka_info["f_population"]

# %%
plt.scatter(m_p,f_p)

# %% [markdown]
# # ４−２

# %%
age = mitaka_info["age"]
plt.scatter(age,m_p)

# %% [markdown]
# # ４−３

# %%
df_1 = pd.read_csv("tokyotemp.csv")
df_2 = df_1.drop("max_temp",axis=1)
df_2
# Out:
#       month  ave_temp
# 0     8-Jan       5.9
# 1     8-Feb       5.5
# 2     8-Mar      10.7
# 3     8-Apr      14.7
# 4     8-May      18.5
# 5     8-Jun      21.3
# 6     8-Jul      27.0
# 7     8-Aug      26.8
# 8     8-Sep      24.4
# 9     8-Oct      19.4
# 10    8-Nov      13.1
# 11    8-Dec       9.8
# 12    9-Jan       6.8
# 13    9-Feb       7.8
# 14    9-Mar      10.0
# 15    9-Apr      15.7
# 16    9-May      20.1
# 17    9-Jun      22.5
# 18    9-Jul      26.3
# 19    9-Aug      26.6
# 20    9-Sep      23.0
# 21    9-Oct      19.0
# 22    9-Nov      13.5
# 23    9-Dec       9.0
# 24   10-Jan       7.0
# 25   10-Feb       6.5
# 26   10-Mar       9.1
# 27   10-Apr      12.4
# 28   10-May      19.0
# 29   10-Jun      23.6
# ..      ...       ...
# 90   15-Jul      26.2
# 91   15-Aug      26.7
# 92   15-Sep      22.6
# 93   15-Oct      18.4
# 94   15-Nov      13.9
# 95   15-Dec       9.3
# 96   16-Jan       6.1
# 97   16-Feb       7.2
# 98   16-Mar      10.1
# ...

# %%
df_2["month"] = df_2["month"].str.replace("8-","")
df_2["month"] = df_2["month"].str.replace("9-","")
df_2["month"] = df_2["month"].str.replace("10-","")
df_2["month"] = df_2["month"].str.replace("11-","")
df_2["month"] = df_2["month"].str.replace("12-","")
df_2["month"] = df_2["month"].str.replace("13-","")
df_2["month"] = df_2["month"].str.replace("14-","")
df_2["month"] = df_2["month"].str.replace("15-","")
df_2["month"] = df_2["month"].str.replace("16-","")
df_2["month"] = df_2["month"].str.replace("17-","")
df_2
# Out:
#     month  ave_temp
# 0     Jan       5.9
# 1     Feb       5.5
# 2     Mar      10.7
# 3     Apr      14.7
# 4     May      18.5
# 5     Jun      21.3
# 6     Jul      27.0
# 7     Aug      26.8
# 8     Sep      24.4
# 9     Oct      19.4
# 10    Nov      13.1
# 11    Dec       9.8
# 12    Jan       6.8
# 13    Feb       7.8
# 14    Mar      10.0
# 15    Apr      15.7
# 16    May      20.1
# 17    Jun      22.5
# 18    Jul      26.3
# 19    Aug      26.6
# 20    Sep      23.0
# 21    Oct      19.0
# 22    Nov      13.5
# 23    Dec       9.0
# 24    Jan       7.0
# 25    Feb       6.5
# 26    Mar       9.1
# 27    Apr      12.4
# 28    May      19.0
# 29    Jun      23.6
# ..    ...       ...
# 90    Jul      26.2
# 91    Aug      26.7
# 92    Sep      22.6
# 93    Oct      18.4
# 94    Nov      13.9
# 95    Dec       9.3
# 96    Jan       6.1
# 97    Feb       7.2
# 98    Mar      10.1
# 99    Apr      15.4
# 100   May      20.2
# 101   Jun      22.4
# 102   Jul      25.4
# ...

# %%
each_month

# %%
jan = df_2[df_2["month"].str.contains("Jan")]
feb = df_2[df_2["month"].str.contains("Feb")]
mar = df_2[df_2["month"].str.contains("Mar")]
apr = df_2[df_2["month"].str.contains("Apr")]
may = df_2[df_2["month"].str.contains("May")]
jun = df_2[df_2["month"].str.contains("Jun")]
july = df_2[df_2["month"].str.contains("July")]
aug = df_2[df_2["month"].str.contains("Aug")]
sep = df_2[df_2["month"].str.contains("Sep")]
Oct = df_2[df_2["month"].str.contains("Oct")]
nov = df_2[df_2["month"].str.contains("Nov")]
dec = df_2[df_2["month"].str.contains("Dec")]
